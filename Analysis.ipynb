# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   datetime64[ns]
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df['Order Year'] = df['Order Date'].dt.year

# %%
df['Order Year'].unique()
# Out:
# array([2017, 2016, 2015, 2018], dtype=int64)

# %%
df['Order Month'] = df['Order Date'].dt.month

# %%
df['Order weekday'] = df['Order Date'].dt.weekday

# %%
weekname = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
lst = []
for item in df['Order weekday'].iteritems():
    lst.append(weekname[item[1]])
df['Order weekname'] = lst

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df['Order day'] = df['Order Date'].dt.day

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# ...

# %%
month = [' ','Januray', 'Febuary', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
lst = []
for item in df['Order Month'].iteritems():
    lst.append(month[item[1]])
    #print(item[1])
df['Order Month'] = lst

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df.to_csv('data.csv')

# %%
df1 = pd.read_csv('data.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0           0       1  CA-2017-152156  2017-08-11  11/11/2017    Second Class
# 1           1       2  CA-2017-152156  2017-08-11  11/11/2017    Second Class
# 2           2       3  CA-2017-138688  2017-12-06  16/06/2017    Second Class
# 3           3       4  US-2016-108966  2016-11-10  18/10/2016  Standard Class
# 4           4       5  US-2016-108966  2016-11-10  18/10/2016  Standard Class
#
#   Customer ID    Customer Name    Segment        Country  ...  \
# 0    CG-12520      Claire Gute   Consumer  United States  ...
# 1    CG-12520      Claire Gute   Consumer  United States  ...
# 2    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#         Product ID         Category  Sub-Category  \
# 0  FUR-BO-10001798        Furniture     Bookcases
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9800 non-null   int64
#  1   Row ID          9800 non-null   int64
#  2   Order ID        9800 non-null   object
#  3   Order Date      9800 non-null   object
#  4   Ship Date       9800 non-null   object
#  5   Ship Mode       9800 non-null   object
#  6   Customer ID     9800 non-null   object
#  7   Customer Name   9800 non-null   object
#  8   Segment         9800 non-null   object
#  9   Country         9800 non-null   object
#  10  City            9800 non-null   object
#  11  State           9800 non-null   object
#  12  Postal Code     9789 non-null   float64
#  13  Region          9800 non-null   object
#  14  Product ID      9800 non-null   object
#  15  Category        9800 non-null   object
#  16  Sub-Category    9800 non-null   object
# ...

# %%
list(df1['Order Year']), list(df1['Sales'])
# Out:
# ([2017,
#   2017,
#   2017,
#   2016,
#   2016,
#   2015,
#   2015,
#   2015,
#   2015,
#   2015,
#   2015,
#   2015,
#   2018,
#   2017,
#   2016,
#   2016,
#   2015,
#   2015,
#   2015,
#   2015,
#   2015,
#   2017,
#   2017,
#   2018,
#   2016,
#   2017,
#   2017,
#   2016,
#   2016,
#   2016,
#   2016,
#   2016,
#   2016,
#   2016,
#   2018,
#   2017,
#   2017,
#   2016,
#   2016,
#   2016,
#   2016,
#   2018,
#   2017,
#   2018,
#   2017,
#   2017,
#   2015,
#   2017,
#   2017,
#   2016,
#   2016,
#   2016,
#   2016,
#   2017,
#   2017,
#   2017,
#   2017,
#   2017,
#   2017,
#   2017,
#   2017,
#   2017,
#   2016,
#   2016,
#   2016,
#   2016,
#   2016,
#   2015,
#   2015,
#   2017,
#   2017,
#   2018,
#   2016,
#   2016,
#   2016,
#   2018,
#   2018,
#   2018,
#   2015,
#   2017,
#   2017,
#   2015,
#   2015,
#   2016,
#   2018,
#   2018,
#   2018,
#   2018,
#   2017,
#   2017,
#   2017,
#   2017,
#   2016,
#   2016,
#   2016,
#   2018,
#   2018,
#   2018,
#   2017,
#   2017,
# ...

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0           0       1  CA-2017-152156  2017-08-11  11/11/2017    Second Class
# 1           1       2  CA-2017-152156  2017-08-11  11/11/2017    Second Class
# 2           2       3  CA-2017-138688  2017-12-06  16/06/2017    Second Class
# 3           3       4  US-2016-108966  2016-11-10  18/10/2016  Standard Class
# 4           4       5  US-2016-108966  2016-11-10  18/10/2016  Standard Class
#
#   Customer ID    Customer Name    Segment        Country  ...  \
# 0    CG-12520      Claire Gute   Consumer  United States  ...
# 1    CG-12520      Claire Gute   Consumer  United States  ...
# 2    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#         Product ID         Category  Sub-Category  \
# 0  FUR-BO-10001798        Furniture     Bookcases
# ...

# %%
df.sort_values(by=['Order weekday'], inplace=True)

# %%
df1 = pd.DataFrame(df.groupby(['Order weekday','Order weekname'])['Sales'].sum())

# %%
df1.reset_index(level=0, drop=True, inplace=True)

# %%
df1.reset_index(inplace=True)
# Out:
#   Order weekname        Sales
# 0         Monday  355652.7196
# 1        Tuesday  369922.1088
# 2      Wednesday  332748.5115
# 3       Thursday  228501.1603
# 4         Friday  257430.3623
# 5       Saturday  394511.1171
# 6         Sunday  322770.8031

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df1 = pd.DataFrame(df.groupby(['Category'])['Sales'].sum())

# %%
df1
# Out:
#                        Sales
# Category
# Furniture        728658.5757
# Office Supplies  705422.3340
# Technology       827455.8730

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#           Category        Sales
# 0        Furniture  728658.5757
# 1  Office Supplies  705422.3340
# 2       Technology  827455.8730

# %%
df1['Sales Percent'] = np.round((df1['Sales']/df1['Sales'].sum()) * 100)

# %%
df1
# Out:
#           Category        Sales  Sales Percent
# 0        Furniture  728658.5757           32.0
# 1  Office Supplies  705422.3340           31.0
# 2       Technology  827455.8730           37.0

# %%
df['Order Year'].unique()
# Out:
# array([2018, 2017, 2016, 2015], dtype=int64)

# %%
df1 = pd.DataFrame(df.groupby(['Order Year'])['Sales'].sum())

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#    Order Year        Sales
# 0        2015  479856.2081
# 1        2016  459436.0054
# 2        2017  600192.5500
# 3        2018  722052.0192

# %%
data = {'bar':{'labels':['a','b','c'], 'values':[23,34,54]}, 'line':{'labels':[23,34], 'values':[45,56]}, 'Pie':{'labels':[99,104], 'values':[15,96]}}

# %%
for label in data['bar']['labels']:
    print(label)
for values in data['bar']['values']:
    print(values)
# Out:
# a
# b
# c
# 23
# 34
# 54

# %%
df.head()
# Out:
#       Unnamed: 0  Row ID        Order ID  Order Date   Ship Date  \
# 1244        1244    1245  CA-2018-133641  2018-05-14  21/05/2018
# 1140        1140    1141  CA-2017-152170  2017-12-11  15/11/2017
# 1139        1139    1140  CA-2017-152170  2017-12-11  15/11/2017
# 1138        1138    1139  CA-2017-152170  2017-12-11  15/11/2017
# 1137        1137    1138  CA-2017-152170  2017-12-11  15/11/2017
#
#            Ship Mode Customer ID Customer Name    Segment        Country  ...  \
# 1244  Standard Class    EJ-14155    Eva Jacobs   Consumer  United States  ...
# 1140    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1139    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1138    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1137    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
#
#            Product ID         Category  Sub-Category  \
# ...

# %%
df1 = pd.DataFrame(df.groupby(['Customer ID', 'Customer Name'])['Sales'].sum())

# %%
df1.reset_index(inplace=True)

# %%
df1 = df1.sort_values('Sales', ascending=False)[:10]

# %%
df1['Sales'] = np.round(df1['Sales'],0)
df1
# Out:
#     Customer ID       Customer Name    Sales
# 700    SM-20320         Sean Miller  25043.0
# 741    TC-20980        Tamara Chand  19052.0
# 621    RB-19360        Raymond Buch  15117.0
# 730    TA-21385        Tom Ashbrook  14596.0
# 6      AB-10105       Adrian Barton  14474.0
# 434    KL-16645        Ken Lonsdale  14175.0
# 669    SC-20095        Sanjit Chand  14142.0
# 327    HL-15040        Hunter Lopez  12873.0
# 683    SE-20110        Sanjit Engle  12209.0
# 131    CC-12370  Christopher Conant  12129.0

# %%
df1['Sales'] = df1['Sales'].astype('int')

# %%
df1['Sales'] = df1['Sales'].astype('str')
df1
# Out:
#     Customer ID       Customer Name  Sales
# 700    SM-20320         Sean Miller  25043
# 741    TC-20980        Tamara Chand  19052
# 621    RB-19360        Raymond Buch  15117
# 730    TA-21385        Tom Ashbrook  14596
# 6      AB-10105       Adrian Barton  14474
# 434    KL-16645        Ken Lonsdale  14175
# 669    SC-20095        Sanjit Chand  14142
# 327    HL-15040        Hunter Lopez  12873
# 683    SE-20110        Sanjit Engle  12209
# 131    CC-12370  Christopher Conant  12129

# %%
df1['Sales'] = df1['Sales'].apply(lambda x: x+"$")

# %%
df1.reset_index(drop=True, inplace=True)
df1
# Out:
#   Customer ID       Customer Name   Sales
# 0    SM-20320         Sean Miller  25043$
# 1    TC-20980        Tamara Chand  19052$
# 2    RB-19360        Raymond Buch  15117$
# 3    TA-21385        Tom Ashbrook  14596$
# 4    AB-10105       Adrian Barton  14474$
# 5    KL-16645        Ken Lonsdale  14175$
# 6    SC-20095        Sanjit Chand  14142$
# 7    HL-15040        Hunter Lopez  12873$
# 8    SE-20110        Sanjit Engle  12209$
# 9    CC-12370  Christopher Conant  12129$

# %%
list(df1.columns)
# Out:
# ['Customer ID', 'Customer Name', 'Sales']

# %%
df1.values.tolist()
# Out:
# [['SM-20320', 'Sean Miller', '25043$'],
#  ['TC-20980', 'Tamara Chand', '19052$'],
#  ['RB-19360', 'Raymond Buch', '15117$'],
#  ['TA-21385', 'Tom Ashbrook', '14596$'],
#  ['AB-10105', 'Adrian Barton', '14474$'],
#  ['KL-16645', 'Ken Lonsdale', '14175$'],
#  ['SC-20095', 'Sanjit Chand', '14142$'],
#  ['HL-15040', 'Hunter Lopez', '12873$'],
#  ['SE-20110', 'Sanjit Engle', '12209$'],
#  ['CC-12370', 'Christopher Conant', '12129$']]

# %%
df1 = pd.DataFrame(df.groupby('State')['Sales'].sum())

# %%
df1.reset_index(inplace=True)

# %%
df1.sort_values('Sales',ascending=False, inplace=True)

# %%
df1 = df1.reset_index(drop=True)[:20]

# %%
df1['Sales'] = np.round(df1['Sales'],2)

# %%
df1
# Out:
#              State      Sales
# 0       California  446306.46
# 1         New York  306361.15
# 2            Texas  168572.53
# 3       Washington  135206.85
# 4     Pennsylvania  116276.65
# 5          Florida   88436.53
# 6         Illinois   79236.52
# 7         Michigan   76136.07
# 8             Ohio   75130.35
# 9         Virginia   70636.72
# 10  North Carolina   55165.96
# 11         Indiana   48718.40
# 12         Georgia   48219.11
# 13        Kentucky   36458.39
# 14         Arizona   35272.66
# 15      New Jersey   34610.97
# 16        Colorado   31841.60
# 17       Wisconsin   31173.43
# 18       Tennessee   30661.87
# 19       Minnesota   29863.15

# %%
df.head()
# Out:
#       Unnamed: 0  Row ID        Order ID  Order Date   Ship Date  \
# 1244        1244    1245  CA-2018-133641  2018-05-14  21/05/2018
# 1140        1140    1141  CA-2017-152170  2017-12-11  15/11/2017
# 1139        1139    1140  CA-2017-152170  2017-12-11  15/11/2017
# 1138        1138    1139  CA-2017-152170  2017-12-11  15/11/2017
# 1137        1137    1138  CA-2017-152170  2017-12-11  15/11/2017
#
#            Ship Mode Customer ID Customer Name    Segment        Country  ...  \
# 1244  Standard Class    EJ-14155    Eva Jacobs   Consumer  United States  ...
# 1140    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1139    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1138    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1137    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
#
#            Product ID         Category  Sub-Category  \
# ...

# %%
df1 = pd.DataFrame(df.groupby(['Category'])['Sales'].sum())

# %%
df1.reset_index()
# Out:
#           Category        Sales
# 0        Furniture  728658.5757
# 1  Office Supplies  705422.3340
# 2       Technology  827455.8730

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Row ID', 'Order ID', 'Order Date', 'Ship Date',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country',
#        'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Order Year', 'Order Month',
#        'Order weekday', 'Order weekname', 'Order day'],
#       dtype='object')

# %%
df.head()
# Out:
#       Unnamed: 0  Row ID        Order ID  Order Date   Ship Date  \
# 1244        1244    1245  CA-2018-133641  2018-05-14  21/05/2018
# 1140        1140    1141  CA-2017-152170  2017-12-11  15/11/2017
# 1139        1139    1140  CA-2017-152170  2017-12-11  15/11/2017
# 1138        1138    1139  CA-2017-152170  2017-12-11  15/11/2017
# 1137        1137    1138  CA-2017-152170  2017-12-11  15/11/2017
#
#            Ship Mode Customer ID Customer Name    Segment        Country  ...  \
# 1244  Standard Class    EJ-14155    Eva Jacobs   Consumer  United States  ...
# 1140    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1139    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1138    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1137    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
#
#            Product ID         Category  Sub-Category  \
# ...

# %%
df1 = pd.DataFrame(df.groupby(['Order Month'])['Sales'].sum())

# %%
df1.reset_index(inplace=True)

# %%
months_num = [4,8,12,2,1,7,6,3,5,11,10,9]
df1['months_num'] = months_num

# %%
df1.sort_values('months_num', inplace=True)

# %%
df1
# Out:
#    Order Month        Sales  months_num
# 4      Januray  155990.9154           1
# 3      Febuary  131153.2594           2
# 7        March  212256.1344           3
# 0        April  142984.2481           4
# 8          May  166000.7467           5
# 6         June  142034.7713           6
# 5         July  159472.5865           7
# 1       August  207601.7939           8
# 11   September  245155.0671           9
# 10     October  183851.9562          10
# 9     November  268768.7885          11
# 2     December  246266.5152          12

# %%
df.head()
# Out:
#       Unnamed: 0  Row ID        Order ID  Order Date   Ship Date  \
# 1244        1244    1245  CA-2018-133641  2018-05-14  21/05/2018
# 1140        1140    1141  CA-2017-152170  2017-12-11  15/11/2017
# 1139        1139    1140  CA-2017-152170  2017-12-11  15/11/2017
# 1138        1138    1139  CA-2017-152170  2017-12-11  15/11/2017
# 1137        1137    1138  CA-2017-152170  2017-12-11  15/11/2017
#
#            Ship Mode Customer ID Customer Name    Segment        Country  ...  \
# 1244  Standard Class    EJ-14155    Eva Jacobs   Consumer  United States  ...
# 1140    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1139    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1138    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
# 1137    Second Class    FH-14275  Frank Hawley  Corporate  United States  ...
#
#            Product ID         Category  Sub-Category  \
# ...

# %%
df_central = pd.DataFrame(df[df['Region']=='Central'].groupby('Order Year')['Sales'].sum())
df_east = pd.DataFrame(df[df['Region']=='East'].groupby('Order Year')['Sales'].sum())
df_south = pd.DataFrame(df[df['Region']=='South'].groupby('Order Year')['Sales'].sum())
df_west = pd.DataFrame(df[df['Region']=='West'].groupby('Order Year')['Sales'].sum())

# %%
df_central.reset_index(inplace=True)
df_east.reset_index(inplace=True)
df_south.reset_index(inplace=True)
df_west.reset_index(inplace=True)

# %%
east_sales = list(df_east['Sales'])
south_sales = list(df_south['Sales'])
west_sales = list(df_west['Sales'])

df_central['east_sales'] = east_sales
df_central['west_sales'] = west_sales
df_central['south_sales'] = south_sales

df_central
# Out:
#    Order Year        Sales  east_sales   west_sales  south_sales
# 0        2015  102920.5206  127652.819  145907.9630  103374.9055
# 1        2016  102425.1724  153225.183  133709.5675   70076.0825
# 2        2017  145673.8800  178511.538  182471.2285   93535.9035
# 3        2018  141627.3402  210129.186  248130.9255  122164.5675

# %%
df['Ship Mode']
# Out:
# array(['Standard Class', 'Second Class', 'Same Day', 'First Class'],
#       dtype=object)

# %%
total_revenue = str(int(np.round(df['Sales'].sum(), 0))) + '$'

# %%
total_revenue
# Out:
# '2261537$'

# %%
total_sales = df['Sales'].count()

# %%
total_customers = len(df['Customer Name'].value_counts())

# %% [markdown]
# # Model building

# %%
df['order_date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['ship_date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

# %%
df['YearMonth'] = df['order_date'].apply(lambda x: x.strftime("%Y-%m"))

# %%
features = ['Order ID','Customer ID', 'Product ID', 'order_date', 'ship_date', 'Product Name', 'Country', 'Region', 'State', 'City', 
            'Segment', 'Category', 'Sub-Category', 'Ship Mode', 'YearMonth', 'Order Year', 'Order Month', 'Sales']

df1= df[features]
df1.head()
# Out:
#             Order ID Customer ID       Product ID order_date  ship_date  \
# 1244  CA-2018-133641    EJ-14155  OFF-EN-10004955 2018-05-14 2018-05-21
# 1140  CA-2017-152170    FH-14275  OFF-BI-10002072 2017-12-11 2017-11-15
# 1139  CA-2017-152170    FH-14275  OFF-AR-10003394 2017-12-11 2017-11-15
# 1138  CA-2017-152170    FH-14275  OFF-PA-10001763 2017-12-11 2017-11-15
# 1137  CA-2017-152170    FH-14275  OFF-AP-10002350 2017-12-11 2017-11-15
#
#                                            Product Name        Country  \
# 1244                      Fashion Color Clasp Envelopes  United States
# 1140                      Cardinal Slant-D Ring Binders  United States
# 1139                                         Newell 332  United States
# 1138                                         Xerox 1896  United States
# 1137  Belkin F9H710-06 7 Outlet SurgeMaster Surge Pr...  United States
#
#        Region        State      City    Segment         Category Sub-Category  \
# ...

# %%
if df1.duplicated().sum() > 0:
    df1 = df1.drop_duplicates()

# %%
# prepare data
sales_data = df1[['order_date', 'Sales']]
sales_data = sales_data.set_index('order_date')

# calculating rolling statistics.
roll_mean = sales_data.rolling(window=7).mean()
roll_std = sales_data.rolling(window=7).std()

# plotting rolling statistics with orignal data mean.
plt.figure(figsize=(14, 7), dpi=100)
data_mean = plt.plot(sales_data.resample('W').mean(), label='Original', marker="o", alpha=0.5)
mean = plt.plot(roll_mean.resample('W').mean(), label="Rolling Mean", marker=".")
std = plt.plot(roll_std.resample('W').std(), label="Rolling Standard", alpha=0.5)

plt.title("Rolling Mean Test")
plt.legend()
plt.savefig('static/img/rolling_stats.png')

# %%
dicts = {}
from statsmodels.tsa.stattools import adfuller
print("Augmented Dickey-fuller test result: ")
result = adfuller(sales_data, autolag="AIC")

print("ADF test statistic: ", result[0])
print("p-value:", result[1])

print("Critical Values:")
for key, val in result[4].items():
    print("\t%s : %f" %(key, val))
    dicts[key] = val
# Out:
# Augmented Dickey-fuller test result:
# ADF test statistic:  -97.61999487228783
# p-value: 0.0
# Critical Values:
# 	1% : -3.431018
# 	5% : -2.861835
# 	10% : -2.566927

# %%
dicts
# Out:
# {'1%': -3.4310175866538266,
#  '5%': -2.8618350329195845,
#  '10%': -2.566927040895199}

# %%
import statsmodels.api as sm

import warnings
warnings.filterwarnings('ignore')

sales = pd.DataFrame(df1.groupby(by=['order_date']).sum()['Sales'])

# Fitting ARIMA model
model = sm.tsa.statespace.SARIMAX(sales,order=(1, 0, 0), seasonal_order=(1, 1, 1, 12))
result = model.fit()
print("SARIMAX Summary")
print(result.summary().tables[1])
# Out:
# SARIMAX Summary
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0827      0.030      2.754      0.006       0.024       0.142
# ar.S.L12      -0.0313      0.031     -0.997      0.319      -0.093       0.030
# ma.S.L12      -0.9999      0.014    -69.515      0.000      -1.028      -0.972
# sigma2      5.226e+06   2.76e-09   1.89e+15      0.000    5.23e+06    5.23e+06
# ...

# %%
print(result)

# %%
# Visualization of the performance of our model
result.plot_diagnostics(figsize=(14, 10))
plt.savefig('img/performance.png')

# %%
# #from statsmodels.tsa.sarimax import ARIMAResults
# from statsmodels.tsa.statespace.sarimax import SARIMAXResults
# # SARIMAXResults.save('sarima_model', model, remove_data=False)
# import pickle
# SARIMAXResults.save(fname='sarima_model')

import pickle    
with open('learned_model.pkl','wb') as f:
    pickle.dump(result, f)

# %%
# load saved model
with open('learned_model.pkl' , 'rb') as f:
    lr = pickle.load(f)

# %%
sales = pd.DataFrame(df1.groupby(by=['order_date']).sum()['Sales'])
sales.to_csv('sales.csv')

# %%
sales['Forecast']= pd.DataFrame(lr.predict(start='2018-01-01', end='2018-12-30', dynamic=False))

# visualization for the same
sales.plot(figsize=(14, 8))
plt.savefig('static/img/sales.png')
# sales.to_csv('sales.csv')

# %%
from sklearn.metrics import mean_squared_error
actual = sales.loc['2018-01-01':'2018-12-30']['Sales']
preds = sales.loc['2018-01-01':'2018-12-30']['Forecast']
rmse_sarima = np.sqrt(mean_squared_error(preds, actual))
print("Root Mean Squared Error for SARIMAX:", rmse_sarima)
# Out:
# Root Mean Squared Error for SARIMAX: 2449.9717488042

# %%
import os
os.path.join()

# %%
l = list(lr.predict(start='2018-01-01', end='2018-12-30', dynamic=False))
sales['Forecast'] = pd.DataFrame(l)

# %%
sales['Forecast'].isnull().sum()
# Out:
# 1230

# %%
temp = pd.DataFrame(sales.loc['2018-01-01':'2018-12-30']['Sales'])
temp['for'] = l

# %%
type(temp)
# Out:
# pandas.core.frame.DataFrame

# %%
sales.reset_index(inplace=True)

# %%
index1 = sales['order_date'][sales['order_date']=='2018-01-01'].index
index2 = sales['order_date'][sales['order_date']=='2018-12-30'].index

# %%
actual = sales.loc[index1.tolist()[0]:index2.tolist()[0]]['Sales']

# %%
df = pd.DataFrame(actual)

# %%
df
# Out:
#           Sales
# 908   1481.8280
# 909   5972.9880
# 910   4108.3700
# 911    586.0420
# 912    639.8300
# ...         ...
# 1225   814.5940
# 1226   177.6360
# 1227  1657.3508
# 1228  2915.5340
# 1229   713.7900
#
# [322 rows x 1 columns]
